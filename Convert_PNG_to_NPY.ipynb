# %%
# 1. Import các thư viện cần thiết
import os
import cv2
import numpy as np
import mediapipe as mp
from pathlib import Path
import shutil
from tqdm import tqdm
import glob

print("✅ All packages imported successfully!")
# Out:
# ✅ All packages imported successfully!

# %%
# 2. Khởi tạo MediaPipe
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils
mp_face_mesh = mp.solutions.face_mesh

# Sao chép các hàm xử lý từ Action Detection Refined
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results

def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

print("✅ MediaPipe functions initialized!")
# Out:
# ✅ MediaPipe functions initialized!

# %%
# 3. Hàm đổi tên file thành số tăng dần (CHUẨN SỐ LIÊN TỤC)
def rename_files_to_numbers(dataset_path):
    """
    Đổi tên tất cả file trong mỗi thư mục action thành số tăng dần từ 0: 0, 1, 2, 3, 4...
    """
    dataset_path = Path(dataset_path)
    
    if not dataset_path.exists():
        print(f"❌ Thư mục {dataset_path} không tồn tại!")
        return
    
    action_folders = [f for f in dataset_path.iterdir() if f.is_dir()]
    
    for action_folder in action_folders:
        print(f"🔄 Đang xử lý thư mục: {action_folder.name}")
        
        # Lấy tất cả file ảnh (jpg, png, jpeg)
        image_files = []
        for ext in ['*.jpg', '*.jpeg', '*.png', '*.JPG', '*.JPEG', '*.PNG']:
            image_files.extend(glob.glob(str(action_folder / ext)))
        
        if not image_files:
            print(f"⚠️ Không tìm thấy file ảnh nào trong {action_folder.name}")
            continue
        
        # Sắp xếp để đảm bảo thứ tự nhất quán (theo tên file)
        image_files.sort()
        
        print(f"   Tìm thấy {len(image_files)} file ảnh")
        
        # Đổi tên tạm thời để tránh xung đột (dùng .tmp)
        temp_files = []
        for i, old_path in enumerate(image_files):
            old_file = Path(old_path)
            temp_name = f"temp_rename_{i}.tmp"
            temp_path = old_file.parent / temp_name
            try:
                os.rename(old_path, temp_path)
                temp_files.append((temp_path, old_file.suffix))  # Lưu lại đuôi gốc
            except Exception as e:
                print(f"❌ Lỗi đổi tên tạm {old_path}: {e}")
        
        # Đổi tên tạm thành số liên tục: 0, 1, 2, 3...
        success_count = 0
        for idx, (temp_path, suffix) in enumerate(temp_files):
            final_name = f"{idx}{suffix}"
            final_path = temp_path.parent / final_name
            try:
                os.rename(temp_path, final_path)
                success_count += 1
            except Exception as e:
                print(f"❌ Lỗi đổi tên cuối cùng {temp_path}: {e}")
        
        print(f"✅ {action_folder.name}: Đã đổi tên thành công {success_count}/{len(image_files)} file")
        
        # Kiểm tra kết quả
        final_files = []
        for ext in ['*.jpg', '*.jpeg', '*.png', '*.JPG', '*.JPEG', '*.PNG']:
            final_files.extend(glob.glob(str(action_folder / ext)))
        final_files.sort(key=lambda x: int(Path(x).stem))
        print(f"   Kết quả: {[Path(f).name for f in final_files[:10]]}...")  # Hiển thị 10 file đầu
    
    print("🎉 Hoàn thành đổi tên tất cả file thành số liên tục!")

# Chạy hàm đổi tên với version mới
DATASET_PATH = "asl_dataset"
rename_files_to_numbers(DATASET_PATH)
# Out:
# 🔄 Đang xử lý thư mục: 0
#    Tìm thấy 560 file ảnh
# ❌ Lỗi đổi tên tạm asl_dataset\0\0.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\0.jpeg' -> 'asl_dataset\\0\\temp_rename_1.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\1.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\1.jpeg' -> 'asl_dataset\\0\\temp_rename_3.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\10.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\10.jpeg' -> 'asl_dataset\\0\\temp_rename_5.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\100.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\100.jpeg' -> 'asl_dataset\\0\\temp_rename_7.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\101.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\101.jpeg' -> 'asl_dataset\\0\\temp_rename_9.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\102.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\102.jpeg' -> 'asl_dataset\\0\\temp_rename_11.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\103.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\103.jpeg' -> 'asl_dataset\\0\\temp_rename_13.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\104.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\104.jpeg' -> 'asl_dataset\\0\\temp_rename_15.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\105.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\105.jpeg' -> 'asl_dataset\\0\\temp_rename_17.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\106.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\106.jpeg' -> 'asl_dataset\\0\\temp_rename_19.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\107.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\107.jpeg' -> 'asl_dataset\\0\\temp_rename_21.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\108.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\108.jpeg' -> 'asl_dataset\\0\\temp_rename_23.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\109.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\109.jpeg' -> 'asl_dataset\\0\\temp_rename_25.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\11.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\11.jpeg' -> 'asl_dataset\\0\\temp_rename_27.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\110.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\110.jpeg' -> 'asl_dataset\\0\\temp_rename_29.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\111.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\111.jpeg' -> 'asl_dataset\\0\\temp_rename_31.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\112.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\112.jpeg' -> 'asl_dataset\\0\\temp_rename_33.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\113.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\113.jpeg' -> 'asl_dataset\\0\\temp_rename_35.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\114.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\114.jpeg' -> 'asl_dataset\\0\\temp_rename_37.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\115.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\115.jpeg' -> 'asl_dataset\\0\\temp_rename_39.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\116.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\116.jpeg' -> 'asl_dataset\\0\\temp_rename_41.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\117.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\117.jpeg' -> 'asl_dataset\\0\\temp_rename_43.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\118.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\118.jpeg' -> 'asl_dataset\\0\\temp_rename_45.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\119.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\119.jpeg' -> 'asl_dataset\\0\\temp_rename_47.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\12.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\12.jpeg' -> 'asl_dataset\\0\\temp_rename_49.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\120.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\120.jpeg' -> 'asl_dataset\\0\\temp_rename_51.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\121.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\121.jpeg' -> 'asl_dataset\\0\\temp_rename_53.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\122.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\122.jpeg' -> 'asl_dataset\\0\\temp_rename_55.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\123.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\123.jpeg' -> 'asl_dataset\\0\\temp_rename_57.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\124.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\124.jpeg' -> 'asl_dataset\\0\\temp_rename_59.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\125.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\125.jpeg' -> 'asl_dataset\\0\\temp_rename_61.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\126.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\126.jpeg' -> 'asl_dataset\\0\\temp_rename_63.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\127.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\127.jpeg' -> 'asl_dataset\\0\\temp_rename_65.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\128.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\128.jpeg' -> 'asl_dataset\\0\\temp_rename_67.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\129.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\129.jpeg' -> 'asl_dataset\\0\\temp_rename_69.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\13.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\13.jpeg' -> 'asl_dataset\\0\\temp_rename_71.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\130.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\130.jpeg' -> 'asl_dataset\\0\\temp_rename_73.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\131.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\131.jpeg' -> 'asl_dataset\\0\\temp_rename_75.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\132.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\132.jpeg' -> 'asl_dataset\\0\\temp_rename_77.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\133.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\133.jpeg' -> 'asl_dataset\\0\\temp_rename_79.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\134.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\134.jpeg' -> 'asl_dataset\\0\\temp_rename_81.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\135.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\135.jpeg' -> 'asl_dataset\\0\\temp_rename_83.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\136.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\136.jpeg' -> 'asl_dataset\\0\\temp_rename_85.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\137.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\137.jpeg' -> 'asl_dataset\\0\\temp_rename_87.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\138.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\138.jpeg' -> 'asl_dataset\\0\\temp_rename_89.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\139.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\139.jpeg' -> 'asl_dataset\\0\\temp_rename_91.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\14.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\14.jpeg' -> 'asl_dataset\\0\\temp_rename_93.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\140.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\140.jpeg' -> 'asl_dataset\\0\\temp_rename_95.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\141.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\141.jpeg' -> 'asl_dataset\\0\\temp_rename_97.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\142.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\142.jpeg' -> 'asl_dataset\\0\\temp_rename_99.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\143.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\143.jpeg' -> 'asl_dataset\\0\\temp_rename_101.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\144.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\144.jpeg' -> 'asl_dataset\\0\\temp_rename_103.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\145.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\145.jpeg' -> 'asl_dataset\\0\\temp_rename_105.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\146.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\146.jpeg' -> 'asl_dataset\\0\\temp_rename_107.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\147.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\147.jpeg' -> 'asl_dataset\\0\\temp_rename_109.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\148.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\148.jpeg' -> 'asl_dataset\\0\\temp_rename_111.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\149.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\149.jpeg' -> 'asl_dataset\\0\\temp_rename_113.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\15.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\15.jpeg' -> 'asl_dataset\\0\\temp_rename_115.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\150.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\150.jpeg' -> 'asl_dataset\\0\\temp_rename_117.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\151.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\151.jpeg' -> 'asl_dataset\\0\\temp_rename_119.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\152.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\152.jpeg' -> 'asl_dataset\\0\\temp_rename_121.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\153.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\153.jpeg' -> 'asl_dataset\\0\\temp_rename_123.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\154.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\154.jpeg' -> 'asl_dataset\\0\\temp_rename_125.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\155.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\155.jpeg' -> 'asl_dataset\\0\\temp_rename_127.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\156.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\156.jpeg' -> 'asl_dataset\\0\\temp_rename_129.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\157.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\157.jpeg' -> 'asl_dataset\\0\\temp_rename_131.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\158.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\158.jpeg' -> 'asl_dataset\\0\\temp_rename_133.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\159.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\159.jpeg' -> 'asl_dataset\\0\\temp_rename_135.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\16.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\16.jpeg' -> 'asl_dataset\\0\\temp_rename_137.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\160.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\160.jpeg' -> 'asl_dataset\\0\\temp_rename_139.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\161.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\161.jpeg' -> 'asl_dataset\\0\\temp_rename_141.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\162.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\162.jpeg' -> 'asl_dataset\\0\\temp_rename_143.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\163.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\163.jpeg' -> 'asl_dataset\\0\\temp_rename_145.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\164.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\164.jpeg' -> 'asl_dataset\\0\\temp_rename_147.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\165.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\165.jpeg' -> 'asl_dataset\\0\\temp_rename_149.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\166.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\166.jpeg' -> 'asl_dataset\\0\\temp_rename_151.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\167.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\167.jpeg' -> 'asl_dataset\\0\\temp_rename_153.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\168.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\168.jpeg' -> 'asl_dataset\\0\\temp_rename_155.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\169.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\169.jpeg' -> 'asl_dataset\\0\\temp_rename_157.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\17.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\17.jpeg' -> 'asl_dataset\\0\\temp_rename_159.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\170.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\170.jpeg' -> 'asl_dataset\\0\\temp_rename_161.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\171.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\171.jpeg' -> 'asl_dataset\\0\\temp_rename_163.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\172.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\172.jpeg' -> 'asl_dataset\\0\\temp_rename_165.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\173.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\173.jpeg' -> 'asl_dataset\\0\\temp_rename_167.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\174.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\174.jpeg' -> 'asl_dataset\\0\\temp_rename_169.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\175.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\175.jpeg' -> 'asl_dataset\\0\\temp_rename_171.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\176.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\176.jpeg' -> 'asl_dataset\\0\\temp_rename_173.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\177.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\177.jpeg' -> 'asl_dataset\\0\\temp_rename_175.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\178.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\178.jpeg' -> 'asl_dataset\\0\\temp_rename_177.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\179.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\179.jpeg' -> 'asl_dataset\\0\\temp_rename_179.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\18.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\18.jpeg' -> 'asl_dataset\\0\\temp_rename_181.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\180.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\180.jpeg' -> 'asl_dataset\\0\\temp_rename_183.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\181.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\181.jpeg' -> 'asl_dataset\\0\\temp_rename_185.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\182.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\182.jpeg' -> 'asl_dataset\\0\\temp_rename_187.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\183.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\183.jpeg' -> 'asl_dataset\\0\\temp_rename_189.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\184.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\184.jpeg' -> 'asl_dataset\\0\\temp_rename_191.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\185.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\185.jpeg' -> 'asl_dataset\\0\\temp_rename_193.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\186.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\186.jpeg' -> 'asl_dataset\\0\\temp_rename_195.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\187.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\187.jpeg' -> 'asl_dataset\\0\\temp_rename_197.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\188.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\188.jpeg' -> 'asl_dataset\\0\\temp_rename_199.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\189.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\189.jpeg' -> 'asl_dataset\\0\\temp_rename_201.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\19.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\19.jpeg' -> 'asl_dataset\\0\\temp_rename_203.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\190.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\190.jpeg' -> 'asl_dataset\\0\\temp_rename_205.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\191.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\191.jpeg' -> 'asl_dataset\\0\\temp_rename_207.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\192.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\192.jpeg' -> 'asl_dataset\\0\\temp_rename_209.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\193.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\193.jpeg' -> 'asl_dataset\\0\\temp_rename_211.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\194.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\194.jpeg' -> 'asl_dataset\\0\\temp_rename_213.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\195.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\195.jpeg' -> 'asl_dataset\\0\\temp_rename_215.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\196.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\196.jpeg' -> 'asl_dataset\\0\\temp_rename_217.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\197.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\197.jpeg' -> 'asl_dataset\\0\\temp_rename_219.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\198.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\198.jpeg' -> 'asl_dataset\\0\\temp_rename_221.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\199.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\199.jpeg' -> 'asl_dataset\\0\\temp_rename_223.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\2.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\2.jpeg' -> 'asl_dataset\\0\\temp_rename_225.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\20.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\20.jpeg' -> 'asl_dataset\\0\\temp_rename_227.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\200.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\200.jpeg' -> 'asl_dataset\\0\\temp_rename_229.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\201.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\201.jpeg' -> 'asl_dataset\\0\\temp_rename_231.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\202.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\202.jpeg' -> 'asl_dataset\\0\\temp_rename_233.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\203.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\203.jpeg' -> 'asl_dataset\\0\\temp_rename_235.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\204.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\204.jpeg' -> 'asl_dataset\\0\\temp_rename_237.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\205.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\205.jpeg' -> 'asl_dataset\\0\\temp_rename_239.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\206.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\206.jpeg' -> 'asl_dataset\\0\\temp_rename_241.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\207.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\207.jpeg' -> 'asl_dataset\\0\\temp_rename_243.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\208.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\208.jpeg' -> 'asl_dataset\\0\\temp_rename_245.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\209.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\209.jpeg' -> 'asl_dataset\\0\\temp_rename_247.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\21.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\21.jpeg' -> 'asl_dataset\\0\\temp_rename_249.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\210.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\210.jpeg' -> 'asl_dataset\\0\\temp_rename_251.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\211.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\211.jpeg' -> 'asl_dataset\\0\\temp_rename_253.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\212.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\212.jpeg' -> 'asl_dataset\\0\\temp_rename_255.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\213.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\213.jpeg' -> 'asl_dataset\\0\\temp_rename_257.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\214.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\214.jpeg' -> 'asl_dataset\\0\\temp_rename_259.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\215.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\215.jpeg' -> 'asl_dataset\\0\\temp_rename_261.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\216.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\216.jpeg' -> 'asl_dataset\\0\\temp_rename_263.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\217.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\217.jpeg' -> 'asl_dataset\\0\\temp_rename_265.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\218.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\218.jpeg' -> 'asl_dataset\\0\\temp_rename_267.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\219.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\219.jpeg' -> 'asl_dataset\\0\\temp_rename_269.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\22.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\22.jpeg' -> 'asl_dataset\\0\\temp_rename_271.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\220.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\220.jpeg' -> 'asl_dataset\\0\\temp_rename_273.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\221.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\221.jpeg' -> 'asl_dataset\\0\\temp_rename_275.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\222.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\222.jpeg' -> 'asl_dataset\\0\\temp_rename_277.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\223.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\223.jpeg' -> 'asl_dataset\\0\\temp_rename_279.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\224.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\224.jpeg' -> 'asl_dataset\\0\\temp_rename_281.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\225.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\225.jpeg' -> 'asl_dataset\\0\\temp_rename_283.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\226.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\226.jpeg' -> 'asl_dataset\\0\\temp_rename_285.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\227.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\227.jpeg' -> 'asl_dataset\\0\\temp_rename_287.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\228.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\228.jpeg' -> 'asl_dataset\\0\\temp_rename_289.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\229.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\229.jpeg' -> 'asl_dataset\\0\\temp_rename_291.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\23.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\23.jpeg' -> 'asl_dataset\\0\\temp_rename_293.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\230.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\230.jpeg' -> 'asl_dataset\\0\\temp_rename_295.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\231.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\231.jpeg' -> 'asl_dataset\\0\\temp_rename_297.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\232.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\232.jpeg' -> 'asl_dataset\\0\\temp_rename_299.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\233.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\233.jpeg' -> 'asl_dataset\\0\\temp_rename_301.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\234.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\234.jpeg' -> 'asl_dataset\\0\\temp_rename_303.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\235.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\235.jpeg' -> 'asl_dataset\\0\\temp_rename_305.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\236.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\236.jpeg' -> 'asl_dataset\\0\\temp_rename_307.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\237.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\237.jpeg' -> 'asl_dataset\\0\\temp_rename_309.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\238.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\238.jpeg' -> 'asl_dataset\\0\\temp_rename_311.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\239.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\239.jpeg' -> 'asl_dataset\\0\\temp_rename_313.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\24.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\24.jpeg' -> 'asl_dataset\\0\\temp_rename_315.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\240.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\240.jpeg' -> 'asl_dataset\\0\\temp_rename_317.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\241.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\241.jpeg' -> 'asl_dataset\\0\\temp_rename_319.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\242.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\242.jpeg' -> 'asl_dataset\\0\\temp_rename_321.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\243.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\243.jpeg' -> 'asl_dataset\\0\\temp_rename_323.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\244.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\244.jpeg' -> 'asl_dataset\\0\\temp_rename_325.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\245.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\245.jpeg' -> 'asl_dataset\\0\\temp_rename_327.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\246.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\246.jpeg' -> 'asl_dataset\\0\\temp_rename_329.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\247.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\247.jpeg' -> 'asl_dataset\\0\\temp_rename_331.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\248.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\248.jpeg' -> 'asl_dataset\\0\\temp_rename_333.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\249.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\249.jpeg' -> 'asl_dataset\\0\\temp_rename_335.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\25.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\25.jpeg' -> 'asl_dataset\\0\\temp_rename_337.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\250.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\250.jpeg' -> 'asl_dataset\\0\\temp_rename_339.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\251.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\251.jpeg' -> 'asl_dataset\\0\\temp_rename_341.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\252.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\252.jpeg' -> 'asl_dataset\\0\\temp_rename_343.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\253.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\253.jpeg' -> 'asl_dataset\\0\\temp_rename_345.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\254.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\254.jpeg' -> 'asl_dataset\\0\\temp_rename_347.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\255.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\255.jpeg' -> 'asl_dataset\\0\\temp_rename_349.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\256.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\256.jpeg' -> 'asl_dataset\\0\\temp_rename_351.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\257.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\257.jpeg' -> 'asl_dataset\\0\\temp_rename_353.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\258.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\258.jpeg' -> 'asl_dataset\\0\\temp_rename_355.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\259.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\259.jpeg' -> 'asl_dataset\\0\\temp_rename_357.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\26.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\26.jpeg' -> 'asl_dataset\\0\\temp_rename_359.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\260.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\260.jpeg' -> 'asl_dataset\\0\\temp_rename_361.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\261.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\261.jpeg' -> 'asl_dataset\\0\\temp_rename_363.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\262.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\262.jpeg' -> 'asl_dataset\\0\\temp_rename_365.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\263.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\263.jpeg' -> 'asl_dataset\\0\\temp_rename_367.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\264.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\264.jpeg' -> 'asl_dataset\\0\\temp_rename_369.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\265.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\265.jpeg' -> 'asl_dataset\\0\\temp_rename_371.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\266.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\266.jpeg' -> 'asl_dataset\\0\\temp_rename_373.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\267.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\267.jpeg' -> 'asl_dataset\\0\\temp_rename_375.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\268.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\268.jpeg' -> 'asl_dataset\\0\\temp_rename_377.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\269.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\269.jpeg' -> 'asl_dataset\\0\\temp_rename_379.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\27.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\27.jpeg' -> 'asl_dataset\\0\\temp_rename_381.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\270.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\270.jpeg' -> 'asl_dataset\\0\\temp_rename_383.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\271.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\271.jpeg' -> 'asl_dataset\\0\\temp_rename_385.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\272.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\272.jpeg' -> 'asl_dataset\\0\\temp_rename_387.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\273.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\273.jpeg' -> 'asl_dataset\\0\\temp_rename_389.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\274.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\274.jpeg' -> 'asl_dataset\\0\\temp_rename_391.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\275.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\275.jpeg' -> 'asl_dataset\\0\\temp_rename_393.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\276.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\276.jpeg' -> 'asl_dataset\\0\\temp_rename_395.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\277.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\277.jpeg' -> 'asl_dataset\\0\\temp_rename_397.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\278.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\278.jpeg' -> 'asl_dataset\\0\\temp_rename_399.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\279.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\279.jpeg' -> 'asl_dataset\\0\\temp_rename_401.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\28.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\28.jpeg' -> 'asl_dataset\\0\\temp_rename_403.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\29.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\29.jpeg' -> 'asl_dataset\\0\\temp_rename_405.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\3.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\3.jpeg' -> 'asl_dataset\\0\\temp_rename_407.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\30.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\30.jpeg' -> 'asl_dataset\\0\\temp_rename_409.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\31.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\31.jpeg' -> 'asl_dataset\\0\\temp_rename_411.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\32.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\32.jpeg' -> 'asl_dataset\\0\\temp_rename_413.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\33.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\33.jpeg' -> 'asl_dataset\\0\\temp_rename_415.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\34.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\34.jpeg' -> 'asl_dataset\\0\\temp_rename_417.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\35.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\35.jpeg' -> 'asl_dataset\\0\\temp_rename_419.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\36.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\36.jpeg' -> 'asl_dataset\\0\\temp_rename_421.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\37.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\37.jpeg' -> 'asl_dataset\\0\\temp_rename_423.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\38.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\38.jpeg' -> 'asl_dataset\\0\\temp_rename_425.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\39.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\39.jpeg' -> 'asl_dataset\\0\\temp_rename_427.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\4.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\4.jpeg' -> 'asl_dataset\\0\\temp_rename_429.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\40.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\40.jpeg' -> 'asl_dataset\\0\\temp_rename_431.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\41.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\41.jpeg' -> 'asl_dataset\\0\\temp_rename_433.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\42.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\42.jpeg' -> 'asl_dataset\\0\\temp_rename_435.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\43.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\43.jpeg' -> 'asl_dataset\\0\\temp_rename_437.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\44.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\44.jpeg' -> 'asl_dataset\\0\\temp_rename_439.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\45.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\45.jpeg' -> 'asl_dataset\\0\\temp_rename_441.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\46.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\46.jpeg' -> 'asl_dataset\\0\\temp_rename_443.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\47.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\47.jpeg' -> 'asl_dataset\\0\\temp_rename_445.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\48.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\48.jpeg' -> 'asl_dataset\\0\\temp_rename_447.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\49.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\49.jpeg' -> 'asl_dataset\\0\\temp_rename_449.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\5.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\5.jpeg' -> 'asl_dataset\\0\\temp_rename_451.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\50.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\50.jpeg' -> 'asl_dataset\\0\\temp_rename_453.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\51.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\51.jpeg' -> 'asl_dataset\\0\\temp_rename_455.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\52.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\52.jpeg' -> 'asl_dataset\\0\\temp_rename_457.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\53.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\53.jpeg' -> 'asl_dataset\\0\\temp_rename_459.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\54.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\54.jpeg' -> 'asl_dataset\\0\\temp_rename_461.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\55.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\55.jpeg' -> 'asl_dataset\\0\\temp_rename_463.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\56.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\56.jpeg' -> 'asl_dataset\\0\\temp_rename_465.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\57.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\57.jpeg' -> 'asl_dataset\\0\\temp_rename_467.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\58.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\58.jpeg' -> 'asl_dataset\\0\\temp_rename_469.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\59.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\59.jpeg' -> 'asl_dataset\\0\\temp_rename_471.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\6.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\6.jpeg' -> 'asl_dataset\\0\\temp_rename_473.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\60.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\60.jpeg' -> 'asl_dataset\\0\\temp_rename_475.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\61.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\61.jpeg' -> 'asl_dataset\\0\\temp_rename_477.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\62.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\62.jpeg' -> 'asl_dataset\\0\\temp_rename_479.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\63.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\63.jpeg' -> 'asl_dataset\\0\\temp_rename_481.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\64.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\64.jpeg' -> 'asl_dataset\\0\\temp_rename_483.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\65.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\65.jpeg' -> 'asl_dataset\\0\\temp_rename_485.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\66.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\66.jpeg' -> 'asl_dataset\\0\\temp_rename_487.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\67.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\67.jpeg' -> 'asl_dataset\\0\\temp_rename_489.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\68.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\68.jpeg' -> 'asl_dataset\\0\\temp_rename_491.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\69.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\69.jpeg' -> 'asl_dataset\\0\\temp_rename_493.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\7.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\7.jpeg' -> 'asl_dataset\\0\\temp_rename_495.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\70.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\70.jpeg' -> 'asl_dataset\\0\\temp_rename_497.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\71.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\71.jpeg' -> 'asl_dataset\\0\\temp_rename_499.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\72.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\72.jpeg' -> 'asl_dataset\\0\\temp_rename_501.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\73.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\73.jpeg' -> 'asl_dataset\\0\\temp_rename_503.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\74.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\74.jpeg' -> 'asl_dataset\\0\\temp_rename_505.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\75.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\75.jpeg' -> 'asl_dataset\\0\\temp_rename_507.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\76.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\76.jpeg' -> 'asl_dataset\\0\\temp_rename_509.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\77.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\77.jpeg' -> 'asl_dataset\\0\\temp_rename_511.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\78.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\78.jpeg' -> 'asl_dataset\\0\\temp_rename_513.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\79.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\79.jpeg' -> 'asl_dataset\\0\\temp_rename_515.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\8.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\8.jpeg' -> 'asl_dataset\\0\\temp_rename_517.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\80.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\80.jpeg' -> 'asl_dataset\\0\\temp_rename_519.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\81.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\81.jpeg' -> 'asl_dataset\\0\\temp_rename_521.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\82.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\82.jpeg' -> 'asl_dataset\\0\\temp_rename_523.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\83.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\83.jpeg' -> 'asl_dataset\\0\\temp_rename_525.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\84.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\84.jpeg' -> 'asl_dataset\\0\\temp_rename_527.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\85.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\85.jpeg' -> 'asl_dataset\\0\\temp_rename_529.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\86.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\86.jpeg' -> 'asl_dataset\\0\\temp_rename_531.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\87.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\87.jpeg' -> 'asl_dataset\\0\\temp_rename_533.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\88.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\88.jpeg' -> 'asl_dataset\\0\\temp_rename_535.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\89.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\89.jpeg' -> 'asl_dataset\\0\\temp_rename_537.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\9.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\9.jpeg' -> 'asl_dataset\\0\\temp_rename_539.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\90.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\90.jpeg' -> 'asl_dataset\\0\\temp_rename_541.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\91.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\91.jpeg' -> 'asl_dataset\\0\\temp_rename_543.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\92.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\92.jpeg' -> 'asl_dataset\\0\\temp_rename_545.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\93.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\93.jpeg' -> 'asl_dataset\\0\\temp_rename_547.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\94.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\94.jpeg' -> 'asl_dataset\\0\\temp_rename_549.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\95.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\95.jpeg' -> 'asl_dataset\\0\\temp_rename_551.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\96.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\96.jpeg' -> 'asl_dataset\\0\\temp_rename_553.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\97.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\97.jpeg' -> 'asl_dataset\\0\\temp_rename_555.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\98.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\98.jpeg' -> 'asl_dataset\\0\\temp_rename_557.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\0\99.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\0\\99.jpeg' -> 'asl_dataset\\0\\temp_rename_559.tmp'
# ✅ 0: Đã đổi tên thành công 280/560 file
#    Kết quả: ['0.jpeg', '0.jpeg', '1.jpeg', '1.jpeg', '2.jpeg', '2.jpeg', '3.jpeg', '3.jpeg', '4.jpeg', '4.jpeg']...
# 🔄 Đang xử lý thư mục: 1
#    Tìm thấy 560 file ảnh
# ❌ Lỗi đổi tên tạm asl_dataset\1\0.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\1\\0.jpeg' -> 'asl_dataset\\1\\temp_rename_1.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\1\1.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\1\\1.jpeg' -> 'asl_dataset\\1\\temp_rename_3.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\1\10.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\1\\10.jpeg' -> 'asl_dataset\\1\\temp_rename_5.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\1\100.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\1\\100.jpeg' -> 'asl_dataset\\1\\temp_rename_7.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\1\101.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\1\\101.jpeg' -> 'asl_dataset\\1\\temp_rename_9.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\1\102.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\1\\102.jpeg' -> 'asl_dataset\\1\\temp_rename_11.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\1\103.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\1\\103.jpeg' -> 'asl_dataset\\1\\temp_rename_13.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\1\104.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\1\\104.jpeg' -> 'asl_dataset\\1\\temp_rename_15.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\1\105.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\1\\105.jpeg' -> 'asl_dataset\\1\\temp_rename_17.tmp'
# ...
# ❌ Lỗi đổi tên tạm asl_dataset\z\264.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\264.jpeg' -> 'asl_dataset\\z\\temp_rename_369.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\265.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\265.jpeg' -> 'asl_dataset\\z\\temp_rename_371.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\266.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\266.jpeg' -> 'asl_dataset\\z\\temp_rename_373.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\267.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\267.jpeg' -> 'asl_dataset\\z\\temp_rename_375.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\268.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\268.jpeg' -> 'asl_dataset\\z\\temp_rename_377.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\269.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\269.jpeg' -> 'asl_dataset\\z\\temp_rename_379.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\27.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\27.jpeg' -> 'asl_dataset\\z\\temp_rename_381.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\270.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\270.jpeg' -> 'asl_dataset\\z\\temp_rename_383.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\271.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\271.jpeg' -> 'asl_dataset\\z\\temp_rename_385.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\272.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\272.jpeg' -> 'asl_dataset\\z\\temp_rename_387.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\273.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\273.jpeg' -> 'asl_dataset\\z\\temp_rename_389.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\274.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\274.jpeg' -> 'asl_dataset\\z\\temp_rename_391.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\275.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\275.jpeg' -> 'asl_dataset\\z\\temp_rename_393.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\276.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\276.jpeg' -> 'asl_dataset\\z\\temp_rename_395.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\277.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\277.jpeg' -> 'asl_dataset\\z\\temp_rename_397.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\278.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\278.jpeg' -> 'asl_dataset\\z\\temp_rename_399.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\279.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\279.jpeg' -> 'asl_dataset\\z\\temp_rename_401.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\28.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\28.jpeg' -> 'asl_dataset\\z\\temp_rename_403.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\29.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\29.jpeg' -> 'asl_dataset\\z\\temp_rename_405.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\3.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\3.jpeg' -> 'asl_dataset\\z\\temp_rename_407.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\30.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\30.jpeg' -> 'asl_dataset\\z\\temp_rename_409.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\31.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\31.jpeg' -> 'asl_dataset\\z\\temp_rename_411.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\32.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\32.jpeg' -> 'asl_dataset\\z\\temp_rename_413.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\33.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\33.jpeg' -> 'asl_dataset\\z\\temp_rename_415.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\34.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\34.jpeg' -> 'asl_dataset\\z\\temp_rename_417.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\35.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\35.jpeg' -> 'asl_dataset\\z\\temp_rename_419.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\36.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\36.jpeg' -> 'asl_dataset\\z\\temp_rename_421.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\37.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\37.jpeg' -> 'asl_dataset\\z\\temp_rename_423.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\38.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\38.jpeg' -> 'asl_dataset\\z\\temp_rename_425.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\39.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\39.jpeg' -> 'asl_dataset\\z\\temp_rename_427.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\4.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\4.jpeg' -> 'asl_dataset\\z\\temp_rename_429.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\40.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\40.jpeg' -> 'asl_dataset\\z\\temp_rename_431.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\41.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\41.jpeg' -> 'asl_dataset\\z\\temp_rename_433.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\42.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\42.jpeg' -> 'asl_dataset\\z\\temp_rename_435.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\43.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\43.jpeg' -> 'asl_dataset\\z\\temp_rename_437.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\44.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\44.jpeg' -> 'asl_dataset\\z\\temp_rename_439.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\45.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\45.jpeg' -> 'asl_dataset\\z\\temp_rename_441.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\46.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\46.jpeg' -> 'asl_dataset\\z\\temp_rename_443.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\47.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\47.jpeg' -> 'asl_dataset\\z\\temp_rename_445.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\48.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\48.jpeg' -> 'asl_dataset\\z\\temp_rename_447.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\49.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\49.jpeg' -> 'asl_dataset\\z\\temp_rename_449.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\5.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\5.jpeg' -> 'asl_dataset\\z\\temp_rename_451.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\50.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\50.jpeg' -> 'asl_dataset\\z\\temp_rename_453.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\51.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\51.jpeg' -> 'asl_dataset\\z\\temp_rename_455.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\52.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\52.jpeg' -> 'asl_dataset\\z\\temp_rename_457.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\53.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\53.jpeg' -> 'asl_dataset\\z\\temp_rename_459.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\54.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\54.jpeg' -> 'asl_dataset\\z\\temp_rename_461.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\55.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\55.jpeg' -> 'asl_dataset\\z\\temp_rename_463.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\56.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\56.jpeg' -> 'asl_dataset\\z\\temp_rename_465.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\57.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\57.jpeg' -> 'asl_dataset\\z\\temp_rename_467.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\58.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\58.jpeg' -> 'asl_dataset\\z\\temp_rename_469.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\59.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\59.jpeg' -> 'asl_dataset\\z\\temp_rename_471.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\6.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\6.jpeg' -> 'asl_dataset\\z\\temp_rename_473.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\60.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\60.jpeg' -> 'asl_dataset\\z\\temp_rename_475.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\61.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\61.jpeg' -> 'asl_dataset\\z\\temp_rename_477.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\62.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\62.jpeg' -> 'asl_dataset\\z\\temp_rename_479.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\63.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\63.jpeg' -> 'asl_dataset\\z\\temp_rename_481.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\64.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\64.jpeg' -> 'asl_dataset\\z\\temp_rename_483.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\65.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\65.jpeg' -> 'asl_dataset\\z\\temp_rename_485.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\66.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\66.jpeg' -> 'asl_dataset\\z\\temp_rename_487.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\67.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\67.jpeg' -> 'asl_dataset\\z\\temp_rename_489.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\68.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\68.jpeg' -> 'asl_dataset\\z\\temp_rename_491.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\69.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\69.jpeg' -> 'asl_dataset\\z\\temp_rename_493.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\7.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\7.jpeg' -> 'asl_dataset\\z\\temp_rename_495.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\70.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\70.jpeg' -> 'asl_dataset\\z\\temp_rename_497.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\71.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\71.jpeg' -> 'asl_dataset\\z\\temp_rename_499.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\72.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\72.jpeg' -> 'asl_dataset\\z\\temp_rename_501.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\73.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\73.jpeg' -> 'asl_dataset\\z\\temp_rename_503.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\74.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\74.jpeg' -> 'asl_dataset\\z\\temp_rename_505.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\75.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\75.jpeg' -> 'asl_dataset\\z\\temp_rename_507.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\76.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\76.jpeg' -> 'asl_dataset\\z\\temp_rename_509.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\77.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\77.jpeg' -> 'asl_dataset\\z\\temp_rename_511.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\78.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\78.jpeg' -> 'asl_dataset\\z\\temp_rename_513.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\79.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\79.jpeg' -> 'asl_dataset\\z\\temp_rename_515.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\8.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\8.jpeg' -> 'asl_dataset\\z\\temp_rename_517.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\80.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\80.jpeg' -> 'asl_dataset\\z\\temp_rename_519.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\81.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\81.jpeg' -> 'asl_dataset\\z\\temp_rename_521.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\82.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\82.jpeg' -> 'asl_dataset\\z\\temp_rename_523.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\83.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\83.jpeg' -> 'asl_dataset\\z\\temp_rename_525.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\84.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\84.jpeg' -> 'asl_dataset\\z\\temp_rename_527.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\85.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\85.jpeg' -> 'asl_dataset\\z\\temp_rename_529.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\86.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\86.jpeg' -> 'asl_dataset\\z\\temp_rename_531.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\87.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\87.jpeg' -> 'asl_dataset\\z\\temp_rename_533.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\88.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\88.jpeg' -> 'asl_dataset\\z\\temp_rename_535.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\89.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\89.jpeg' -> 'asl_dataset\\z\\temp_rename_537.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\9.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\9.jpeg' -> 'asl_dataset\\z\\temp_rename_539.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\90.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\90.jpeg' -> 'asl_dataset\\z\\temp_rename_541.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\91.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\91.jpeg' -> 'asl_dataset\\z\\temp_rename_543.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\92.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\92.jpeg' -> 'asl_dataset\\z\\temp_rename_545.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\93.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\93.jpeg' -> 'asl_dataset\\z\\temp_rename_547.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\94.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\94.jpeg' -> 'asl_dataset\\z\\temp_rename_549.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\95.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\95.jpeg' -> 'asl_dataset\\z\\temp_rename_551.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\96.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\96.jpeg' -> 'asl_dataset\\z\\temp_rename_553.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\97.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\97.jpeg' -> 'asl_dataset\\z\\temp_rename_555.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\98.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\98.jpeg' -> 'asl_dataset\\z\\temp_rename_557.tmp'
# ❌ Lỗi đổi tên tạm asl_dataset\z\99.jpeg: [WinError 2] The system cannot find the file specified: 'asl_dataset\\z\\99.jpeg' -> 'asl_dataset\\z\\temp_rename_559.tmp'
# ✅ z: Đã đổi tên thành công 280/560 file
#    Kết quả: ['0.jpeg', '0.jpeg', '1.jpeg', '1.jpeg', '2.jpeg', '2.jpeg', '3.jpeg', '3.jpeg', '4.jpeg', '4.jpeg']...
# 🎉 Hoàn thành đổi tên tất cả file thành số liên tục!

# %%
# 4. Hàm chuyển đổi ảnh sang .npy
def convert_images_to_npy(source_path, output_path):
    """
    Chuyển đổi ảnh từ source_path sang file .npy trong output_path
    với cùng cấu trúc thư mục
    """
    source_path = Path(source_path)
    output_path = Path(output_path)
    
    # Tạo thư mục output nếu chưa có
    output_path.mkdir(exist_ok=True)
    
    # Lấy tất cả thư mục action
    action_folders = [f for f in source_path.iterdir() if f.is_dir()]
    
    total_processed = 0
    total_failed = 0
    
    with mp_holistic.Holistic(
        min_detection_confidence=0.5,
        min_tracking_confidence=0.5
    ) as holistic:
        
        for action_folder in action_folders:
            action_name = action_folder.name
            print(f"\n🔄 Đang xử lý action: {action_name}")
            
            # Tạo thư mục output cho action này
            action_output_path = output_path / action_name
            action_output_path.mkdir(exist_ok=True)
            
            # Lấy tất cả file ảnh
            image_files = []
            for ext in ['*.jpg', '*.jpeg', '*.png', '*.JPG', '*.JPEG', '*.PNG']:
                image_files.extend(glob.glob(str(action_folder / ext)))
            
            image_files.sort(key=lambda x: int(Path(x).stem))  # Sắp xếp theo số
            
            processed_count = 0
            failed_count = 0
            
            for image_path in tqdm(image_files, desc=f"Processing {action_name}"):
                try:
                    # Đọc ảnh
                    image = cv2.imread(image_path)
                    if image is None:
                        print(f"❌ Không thể đọc ảnh: {image_path}")
                        failed_count += 1
                        continue
                    
                    # Xử lý MediaPipe
                    image_rgb, results = mediapipe_detection(image, holistic)
                    
                    # Trích xuất keypoints
                    keypoints = extract_keypoints(results)
                    
                    # Tạo tên file .npy (giữ nguyên số thứ tự)
                    image_name = Path(image_path).stem
                    npy_path = action_output_path / f"{image_name}.npy"
                    
                    # Lưu file .npy
                    np.save(npy_path, keypoints)
                    processed_count += 1
                    
                except Exception as e:
                    print(f"❌ Lỗi xử lý {image_path}: {str(e)}")
                    failed_count += 1
            
            print(f"✅ {action_name}: {processed_count} thành công, {failed_count} thất bại")
            total_processed += processed_count
            total_failed += failed_count
    
    print(f"\n🎉 Hoàn thành! Tổng cộng: {total_processed} thành công, {total_failed} thất bại")
    return total_processed, total_failed

# Chạy chuyển đổi
SOURCE_PATH = "asl_dataset"
OUTPUT_PATH = "asl_dataset_npy"

processed, failed = convert_images_to_npy(SOURCE_PATH, OUTPUT_PATH)
# Out:
# 🔄 Đang xử lý action: 0
# Processing 0: 100%|██████████| 560/560 [00:19<00:00, 29.13it/s]
# ✅ 0: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: 1
# Processing 1: 100%|██████████| 560/560 [00:19<00:00, 28.87it/s]
# ✅ 1: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: 2
# Processing 2: 100%|██████████| 560/560 [00:24<00:00, 22.75it/s]
# ✅ 2: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: 3
# Processing 3: 100%|██████████| 560/560 [00:23<00:00, 23.35it/s]
# ✅ 3: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: 4
# Processing 4: 100%|██████████| 560/560 [00:21<00:00, 26.34it/s]
# ✅ 4: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: 5
# Processing 5: 100%|██████████| 560/560 [00:15<00:00, 36.18it/s]
# ✅ 5: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: 6
# Processing 6: 100%|██████████| 560/560 [00:14<00:00, 38.38it/s]
# ✅ 6: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: 7
# Processing 7: 100%|██████████| 560/560 [00:17<00:00, 31.96it/s]
# ✅ 7: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: 8
# Processing 8: 100%|██████████| 560/560 [00:16<00:00, 33.15it/s]
# ✅ 8: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: 9
# Processing 9: 100%|██████████| 560/560 [00:18<00:00, 30.50it/s]
# ✅ 9: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: a
# Processing a: 100%|██████████| 560/560 [00:15<00:00, 35.11it/s]
# ✅ a: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: b
# Processing b: 100%|██████████| 560/560 [00:14<00:00, 39.41it/s]
# ✅ b: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: c
# Processing c: 100%|██████████| 560/560 [00:10<00:00, 52.31it/s]
# ✅ c: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: d
# Processing d: 100%|██████████| 560/560 [00:16<00:00, 34.28it/s]
# ✅ d: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: e
# Processing e: 100%|██████████| 560/560 [00:23<00:00, 23.73it/s]
# ✅ e: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: f
# Processing f: 100%|██████████| 560/560 [00:18<00:00, 30.60it/s]
# ✅ f: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: g
# Processing g: 100%|██████████| 560/560 [00:17<00:00, 32.83it/s]
# ✅ g: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: h
# Processing h: 100%|██████████| 560/560 [00:16<00:00, 33.68it/s]
# ✅ h: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: i
# Processing i: 100%|██████████| 560/560 [00:16<00:00, 34.62it/s]
# ✅ i: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: j
# Processing j: 100%|██████████| 560/560 [00:15<00:00, 35.49it/s]
# ✅ j: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: k
# Processing k: 100%|██████████| 560/560 [00:17<00:00, 31.55it/s]
# ✅ k: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: l
# Processing l: 100%|██████████| 560/560 [00:16<00:00, 34.11it/s]
# ✅ l: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: m
# Processing m: 100%|██████████| 560/560 [00:11<00:00, 49.33it/s]
# ✅ m: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: n
# Processing n: 100%|██████████| 560/560 [00:11<00:00, 47.23it/s]
# ✅ n: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: o
# Processing o: 100%|██████████| 560/560 [00:11<00:00, 46.99it/s]
# ✅ o: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: p
# Processing p: 100%|██████████| 560/560 [00:15<00:00, 36.19it/s]
# ✅ p: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: q
# Processing q: 100%|██████████| 560/560 [00:11<00:00, 49.54it/s]
# ✅ q: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: r
# Processing r: 100%|██████████| 560/560 [00:18<00:00, 30.07it/s]
# ✅ r: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: s
# Processing s: 100%|██████████| 560/560 [00:12<00:00, 45.56it/s]
# ✅ s: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: t
# Processing t: 100%|██████████| 520/520 [00:16<00:00, 32.25it/s]
# ✅ t: 520 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: u
# Processing u: 100%|██████████| 560/560 [00:18<00:00, 30.53it/s]
# ✅ u: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: v
# Processing v: 100%|██████████| 560/560 [00:17<00:00, 32.35it/s]
# ✅ v: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: w
# Processing w: 100%|██████████| 560/560 [00:16<00:00, 34.83it/s]
# ✅ w: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: x
# Processing x: 100%|██████████| 560/560 [00:15<00:00, 35.88it/s]
# ✅ x: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: y
# Processing y: 100%|██████████| 560/560 [00:17<00:00, 32.46it/s]
# ✅ y: 560 thành công, 0 thất bại
#
# 🔄 Đang xử lý action: z
# Processing z: 100%|██████████| 560/560 [00:16<00:00, 34.14it/s]
# ✅ z: 560 thành công, 0 thất bại
#
# 🎉 Hoàn thành! Tổng cộng: 20120 thành công, 0 thất bại

# %%
# 5. Kiểm tra kết quả
def check_conversion_results(source_path, output_path):
    """
    Kiểm tra kết quả chuyển đổi
    """
    source_path = Path(source_path)
    output_path = Path(output_path)
    
    print("📊 Báo cáo kết quả chuyển đổi:")
    print("-" * 50)
    
    for action_folder in source_path.iterdir():
        if not action_folder.is_dir():
            continue
            
        action_name = action_folder.name
        
        # Đếm file ảnh gốc
        image_count = 0
        for ext in ['*.jpg', '*.jpeg', '*.png', '*.JPG', '*.JPEG', '*.PNG']:
            image_count += len(glob.glob(str(action_folder / ext)))
        
        # Đếm file .npy
        npy_folder = output_path / action_name
        npy_count = len(list(npy_folder.glob('*.npy'))) if npy_folder.exists() else 0
        
        # Hiển thị kết quả
        status = "✅" if image_count == npy_count else "⚠️"
        print(f"{status} {action_name:15} | Ảnh: {image_count:3d} | NPY: {npy_count:3d}")
    
    print("-" * 50)

check_conversion_results(SOURCE_PATH, OUTPUT_PATH)
# Out:
# 📊 Báo cáo kết quả chuyển đổi:
# --------------------------------------------------
# ⚠️ 0               | Ảnh: 560 | NPY: 280
# ⚠️ 1               | Ảnh: 560 | NPY: 280
# ⚠️ 2               | Ảnh: 560 | NPY: 280
# ⚠️ 3               | Ảnh: 560 | NPY: 280
# ⚠️ 4               | Ảnh: 560 | NPY: 280
# ⚠️ 5               | Ảnh: 560 | NPY: 280
# ⚠️ 6               | Ảnh: 560 | NPY: 280
# ⚠️ 7               | Ảnh: 560 | NPY: 280
# ⚠️ 8               | Ảnh: 560 | NPY: 280
# ⚠️ 9               | Ảnh: 560 | NPY: 280
# ⚠️ a               | Ảnh: 560 | NPY: 280
# ⚠️ b               | Ảnh: 560 | NPY: 280
# ⚠️ c               | Ảnh: 560 | NPY: 280
# ⚠️ d               | Ảnh: 560 | NPY: 280
# ⚠️ e               | Ảnh: 560 | NPY: 280
# ⚠️ f               | Ảnh: 560 | NPY: 280
# ⚠️ g               | Ảnh: 560 | NPY: 280
# ⚠️ h               | Ảnh: 560 | NPY: 280
# ⚠️ i               | Ảnh: 560 | NPY: 280
# ⚠️ j               | Ảnh: 560 | NPY: 280
# ⚠️ k               | Ảnh: 560 | NPY: 280
# ⚠️ l               | Ảnh: 560 | NPY: 280
# ⚠️ m               | Ảnh: 560 | NPY: 280
# ⚠️ n               | Ảnh: 560 | NPY: 280
# ⚠️ o               | Ảnh: 560 | NPY: 280
# ⚠️ p               | Ảnh: 560 | NPY: 280
# ⚠️ q               | Ảnh: 560 | NPY: 280
# ⚠️ r               | Ảnh: 560 | NPY: 280
# ⚠️ s               | Ảnh: 560 | NPY: 280
# ⚠️ t               | Ảnh: 520 | NPY: 260
# ⚠️ u               | Ảnh: 560 | NPY: 280
# ⚠️ v               | Ảnh: 560 | NPY: 280
# ⚠️ w               | Ảnh: 560 | NPY: 280
# ⚠️ x               | Ảnh: 560 | NPY: 280
# ⚠️ y               | Ảnh: 560 | NPY: 280
# ⚠️ z               | Ảnh: 560 | NPY: 280
# --------------------------------------------------

# %%
# 6. Test load một file .npy để kiểm tra
def test_npy_file(npy_path):
    """
    Test load một file .npy để kiểm tra tính toàn vẹn
    """
    try:
        data = np.load(npy_path)
        print(f"✅ File: {npy_path}")
        print(f"   Shape: {data.shape}")
        print(f"   Type: {data.dtype}")
        print(f"   Sample values: {data[:5]}")
        print(f"   Has NaN: {np.isnan(data).any()}")
        print(f"   Has Inf: {np.isinf(data).any()}")
        return True
    except Exception as e:
        print(f"❌ Lỗi load file {npy_path}: {str(e)}")
        return False

# Test một file từ mỗi action
output_path = Path(OUTPUT_PATH)
for action_folder in output_path.iterdir():
    if action_folder.is_dir():
        npy_files = list(action_folder.glob('*.npy'))
        if npy_files:
            test_npy_file(npy_files[0])
            break
# Out:
# ✅ File: asl_dataset_npy\0\0.npy
#    Shape: (1662,)
#    Type: float64
#    Sample values: [ 0.53708756  0.25286505 -0.14097157  0.9973911   0.52093697]
#    Has NaN: False
#    Has Inf: False

# %%
# 7. Hàm tạo dataset cho training (tương tự như MP_Data)
def create_training_dataset(npy_source_path, training_output_path, sequence_length=100):
    """
    Tạo dataset training từ các file .npy đơn lẻ
    Nhóm chúng thành các sequence có độ dài cố định
    """
    npy_source_path = Path(npy_source_path)
    training_output_path = Path(training_output_path)
    training_output_path.mkdir(exist_ok=True)
    
    for action_folder in npy_source_path.iterdir():
        if not action_folder.is_dir():
            continue
            
        action_name = action_folder.name
        print(f"🔄 Tạo sequences cho {action_name}")
        
        # Tạo thư mục cho action
        action_training_path = training_output_path / action_name
        action_training_path.mkdir(exist_ok=True)
        
        # Lấy tất cả file .npy và sắp xếp
        npy_files = sorted(action_folder.glob('*.npy'), 
                          key=lambda x: int(x.stem))
        
        if len(npy_files) < sequence_length:
            print(f"⚠️ {action_name} chỉ có {len(npy_files)} file, ít hơn {sequence_length}")
            continue
        
        # Tạo sequences
        sequence_id = 0
        for i in range(0, len(npy_files) - sequence_length + 1, sequence_length):
            sequence_folder = action_training_path / str(sequence_id)
            sequence_folder.mkdir(exist_ok=True)
            
            # Copy 100 file liên tiếp vào sequence
            for j in range(sequence_length):
                source_file = npy_files[i + j]
                target_file = sequence_folder / f"{j}.npy"
                shutil.copy2(source_file, target_file)
            
            sequence_id += 1
        
        print(f"✅ {action_name}: Tạo được {sequence_id} sequences")

# Tạo dataset training
TRAINING_OUTPUT_PATH = "MP_Data_from_images"
create_training_dataset(OUTPUT_PATH, TRAINING_OUTPUT_PATH, sequence_length=100)
# Out:
# 🔄 Tạo sequences cho 0
# ✅ 0: Tạo được 2 sequences
# 🔄 Tạo sequences cho 1
# ✅ 1: Tạo được 2 sequences
# 🔄 Tạo sequences cho 2
# ✅ 2: Tạo được 2 sequences
# 🔄 Tạo sequences cho 3
# ✅ 3: Tạo được 2 sequences
# 🔄 Tạo sequences cho 4
# ✅ 4: Tạo được 2 sequences
# 🔄 Tạo sequences cho 5
# ✅ 5: Tạo được 2 sequences
# 🔄 Tạo sequences cho 6
# ✅ 6: Tạo được 2 sequences
# 🔄 Tạo sequences cho 7
# ✅ 7: Tạo được 2 sequences
# 🔄 Tạo sequences cho 8
# ✅ 8: Tạo được 2 sequences
# 🔄 Tạo sequences cho 9
# ✅ 9: Tạo được 2 sequences
# 🔄 Tạo sequences cho a
# ✅ a: Tạo được 2 sequences
# 🔄 Tạo sequences cho b
# ✅ b: Tạo được 2 sequences
# 🔄 Tạo sequences cho c
# ✅ c: Tạo được 2 sequences
# 🔄 Tạo sequences cho d
# ✅ d: Tạo được 2 sequences
# 🔄 Tạo sequences cho e
# ✅ e: Tạo được 2 sequences
# 🔄 Tạo sequences cho f
# ✅ f: Tạo được 2 sequences
# 🔄 Tạo sequences cho g
# ✅ g: Tạo được 2 sequences
# 🔄 Tạo sequences cho h
# ✅ h: Tạo được 2 sequences
# 🔄 Tạo sequences cho i
# ✅ i: Tạo được 2 sequences
# 🔄 Tạo sequences cho j
# ✅ j: Tạo được 2 sequences
# 🔄 Tạo sequences cho k
# ✅ k: Tạo được 2 sequences
# 🔄 Tạo sequences cho l
# ✅ l: Tạo được 2 sequences
# 🔄 Tạo sequences cho m
# ✅ m: Tạo được 2 sequences
# 🔄 Tạo sequences cho n
# ✅ n: Tạo được 2 sequences
# 🔄 Tạo sequences cho o
# ✅ o: Tạo được 2 sequences
# 🔄 Tạo sequences cho p
# ✅ p: Tạo được 2 sequences
# 🔄 Tạo sequences cho q
# ✅ q: Tạo được 2 sequences
# 🔄 Tạo sequences cho r
# ✅ r: Tạo được 2 sequences
# 🔄 Tạo sequences cho s
# ✅ s: Tạo được 2 sequences
# 🔄 Tạo sequences cho t
# ✅ t: Tạo được 2 sequences
# 🔄 Tạo sequences cho u
# ✅ u: Tạo được 2 sequences
# 🔄 Tạo sequences cho v
# ✅ v: Tạo được 2 sequences
# 🔄 Tạo sequences cho w
# ✅ w: Tạo được 2 sequences
# 🔄 Tạo sequences cho x
# ✅ x: Tạo được 2 sequences
# 🔄 Tạo sequences cho y
# ✅ y: Tạo được 2 sequences
# 🔄 Tạo sequences cho z
# ✅ z: Tạo được 2 sequences
